# %%
import pandas as pd

# %%
df = pd.read_excel("/Users/delmedigo/Dev/langtest/langscrape/data/TAGS.xlsx")

# %%
import pandas as pd

df = pd.read_excel("/Users/delmedigo/Dev/langtest/langscrape/data/TAGS.xlsx")

TYPES = df.TYPES.dropna().tolist()

MEDIAS = df.MEDIAS.dropna().tolist()

LANGUAGES = df.LANGUAGES.dropna().tolist()

PLATFORMS = df.PLATFORMS.dropna().tolist()

THEMES = df.THEMES.dropna().tolist()

COUNTRIES_AND_ORGANIZATIONS = df.COUNTRIES_AND_ORGANIZATIONS.dropna().tolist()

LOCATIONS = df.LOCATIONS.dropna().tolist()

FIGURES = df.FIGURES.dropna().tolist()

# %%
keys = df.columns.tolist()

# %%
# Out:
# ['TYPES',
#  'MEDIAS',
#  'LANGUAGES',
#  'PLATFORMS',
#  'THEMES',
#  'COUNTRIES_AND_ORGANIZATIONS',
#  'LOCATIONS',
#  'FIGURES']

# %%
keys = df.columns.tolist()

DATA_DICT = {key: df[key].dropna().tolist() for key in keys}

# %%
DATA_DICT
# Out:
# {'TYPES': ['Official Report',
#   'Official Statement',
#   'Opinion',
#   'Testimony',
#   'Journalistic Report',
#   'Analysis',
#   'Open Letter',
#   'News',
#   'Post',
#   'Poll',
#   'Press Release',
#   'Interview'],
#  'MEDIAS': ['Video', 'Photo', 'Audio', 'Text', 'Map', 'Chart'],
#  'LANGUAGES': ['English', 'French', 'Hebrew', 'Arabic'],
#  'PLATFORMS': ['972 Magazine',
#   'Al Jazeera',
#   'ABC News',
#   'Academia',
#   'ACLED (Armed Conflict Location and Event Data)',
#   'Adalah',
#   'Airwars',
#   'Alaraby',
#   'AlMamlaka TV',
#   'Al-Monitor',
#   'Al Jazeera',
#   'Amnesty International',
#   'Anadolu Agency',
#   'AP News',
#   'Arab48',
#   'Arab News',
#   'Atlantic Council',
#   "Barron's",
#   'BBC',
#   'Begin-Sadat Center for Strategic Studies (Bar-Ilan University)',
#   'Bellingcat',
#   'Brookings Institute',
#   'Business Insider',
#   'Business Standard',
#   'Calcalist',
#   'Care.org',
#   'CBC News',
#   'CBS',
#   'Center for Economic and Policy Research',
#   'Chabad',
#   'Channel 4',
#   'Channel 14',
#   'CIA',
#   'CNN',
#   'COGAT (The Coordination of the Israeli Government Activities in the Territories)',
#   'Common Dreams',
#   'CPJ',
#   'Daily Sabah',
#   'Daily Trojan',
#   'Decentralize Damage Mapping Group',
#   'Declassified UK',
#   'Defense Daily',
#   'Democracy Now!',
#   'Drop Site News',
#   'DW News',
#   'Euro Gamer',
#   'Euro-Med Human Rights Monitor',
#   'Facebook',
#   'Fair',
#   'Financial Times',
#   'First Draft News',
#   'Foreign Affairs',
#   'Foreign Policy',
#   'Forward',
#   'FOX',
#   'France 24',
#   'FRC (Famine Review Committee)',
#   'Galey Israel',
#   'Galey Tzahal',
#   'Gallup',
#   'Gaza Healthcare Letters',
#   'GazaMaps',
#   'Getty Images',
#   'Global Times',
#   'Globes',
#   'GPO (Government Press Office)',
#   'Haaretz',
#   'Ha-Makom',
#   'Hazman Hazeh',
#   'Hatzinor',
#   'Heritage for Peace',
#   'Hernán Reyes Alcaide',
#   'Hidabroot',
#   'HRF (The Hind Rajab Foundation)',
#   'HuffPost',
#   'Humanity Journal',
#   'Human Rights Center Antonio Papisca',
#   'Human Rights Watch',
#   'IASC (Inter-Agency Standing Committee)',
#   'ice.co.il',
#   'ICRC (the International Committee of the Red Cross)',
#   'iNews',
#   'Inside Higher Ed',
#   'INSS (The Institute for National Security Studies)',
#   'Instagram',
#   'Institute for Palestine Studies',
#   'Institute for the Study of War',
#   'IPC (Integrated Food Security Phase Classification)',
#   'Israel Hayom',
#   'ITV News',
#   'Jacobin',
#   'JDN News',
#   'Jerusalem Center for Public Affairs',
#   'Jewish Currents',
#   'Jewish Voices for Labour',
#   'JPPI (The Jewish People Policy Institute)',
#   'JURIST',
#   'Just Security',
#   'Kan 11',
#   'Ken Klippenstein',
#   'Keshet 12',
#   'Kikar Hashabat',
#   'Knesset Channel 99',
#   'Kol Barama',
#   'La Libre',
#   'La Stampa',
#   'LBC',
#   'Le Monde',
#   'LinkedIn',
#   'Literary Hub',
#   'Los Angeles Times',
#   'Maan News Agency',
#   'Maariv',
#   'Mako',
#   'Makor Rishon',
#   'Mekomit',
#   'Middle East Eye',
#   'Middle East Institute',
#   'Middle East Monitor',
#   'Middle East Studies Association',
#   'Midgam',
#   'Modern War Institute',
#   'Mondoweiss',
#   'MSF - Médecins Sans Frontières (Doctors Without Borders)',
#   'MSNBC',
#   'NBC',
#   'New Line Magazine',
#   'Newsweek',
#   'NPR',
#   'OCHA (UN office for the Coordination of Humanitarian Affairs)',
#   'OnoNews',
#   'Oxfam International',
#   'palestine.beehiiv.com',
#   'Palestine Chronicle',
#   'PBS',
#   'PCATI (The Public Committee Against Torture in Isael)',
#   'Pew Research Center',
#   'PFA - The Foreign Press Association',
#   'Physicians for Human Rights',
#   'PLOS Medicine',
#   'Politicallycorret',
#   'Politico',
#   'ProPublica',
#   'Refugees International',
#   'PSR (Palestine Center for Policy and Seurvey Research)',
#   'Reader Supported News',
#   'Reporters Without Borders',
#   'ReliefWeb',
#   'Reprieve',
#   'Reshet 13',
#   'Responsible Statecraft',
#   'Rolling Stone',
#   'Scribd',
#   'Salon News',
#   'Semafor',
#   'Sky News',
#   'Snopes',
#   'Snd News Agency',
#   'Spotify',
#   'Starts and Stripes',
#   'Substack',
#   'Tablet Magazine',
#   'Telegram',
#   'Telegraph',
#   'The Art Newspaper',
#   'The Association for Civil Rights in Israel',
#   'The Atlantic',
#   'The Baffler',
#   'The Breach',
#   'The Columbia Daily Spectator',
#   'The Column',
#   'The Communist Party of Israel',
#   'The Conversation U.S',
#   'The Daily Beast',
#   'The Daily Pennsylvanian',
#   'The Economist',
#   'The Forum for Regional Thinking',
#   'The Forward',
#   'The Guardian',
#   'The Intercept',
#   'The Israel Democracy Institute',
#   'The Jerusalem post',
#   'The Lancet',
#   'The Marker',
#   'The Nation',
#   'The National',
#   'The New Arab',
#   'The New Republic',
#   'The New Yorker',
#   'The New York Review',
#   'The New York Times',
#   'The New York War Crimes',
#   'The Palestinian Information Center',
#   'The Presidency of the Republic of South Africa',
#   'The Seventh Eye',
#   'The Telegraph',
#   'The Times',
#   'The Times of Israel',
#   'The Wall Street Journal',
#   'The Washington Post',
#   'TikTok',
#   'TIME',
#   'Tribune',
#   'TRT Global',
#   'Twailer',
#   'UN (United Nations)',
#   'UNCTAD (UN Conference of Trade and Development)',
#   'UNDP (UN Development Programme)',
#   "UNICEF (UN International Children's Emergency Fund)",
#   'United States Department of State',
#   'University Network for Human Rights',
#   'UN OHCHR (Office of the High Commissioner for Human Rights)',
#   'UNRWA (The UN Relief and Works Agency for Palestine Refugees)',
#   'USAFacts',
#   'USA Today',
#   'U.S. Central Command',
#   'U.S. News',
#   'WMUR (channel 9)',
#   'Wafa News Agency',
#   'Walla News',
#   'War on the Rocks',
#   'Washington Monthly',
#   'Washington Post',
#   'Watson Institute',
#   'WHO (World Health Organization)',
#   'Wikipedia',
#   'World Food Program',
#   'X',
#   'Yedioth Ahronot',
#   'Yeni Safak',
#   'Ynet',
#   'Yeshiva',
#   'YouTube',
#   'Zeteo',
#   'Zman Israel'],
#  'THEMES': ['2000 Pound Bomb',
#   'Abduction',
#   'Abuse',
#   'Academia',
#   'Accountability',
#   'Administrative Detention',
#   'Advertisement',
#   'Agriculture',
#   'AI (Artificial Intelligence)',
#   'Aid Distribution',
#   'Aid Workers',
#   'Airdrops',
#   'Air Strike',
#   'Amalek',
#   'American Society',
#   'Amputation',
#   'Analysis',
#   'Animals',
#   'Annexation',
#   'Antisemitism',
#   'Apartheid',
#   'Appeal to World Leaders',
#   'Archaeological Findings',
#   'Arms Shipments',
#   'Arrest',
#   'Assassination',
#   'Attacks on Aid Centers',
#   'Attacks on Police',
#   'Blockade',
#   'Blocking Aid',
#   'Bombing',
#   'Books',
#   'Buildings',
#   'Burial',
#   'Burn Injuries',
#   'Burning',
#   'Cages',
#   'Campaign against UNRWA',
#   'Campus Protests',
#   'Captivity Conditions',
#   'Ceasefire',
#   'Cemetery',
#   'Censorship',
#   'Children',
#   'Civilians',
#   'Collective Punishment',
#   'Combat Footage',
#   'Communication Blackout',
#   'Conscientious Objection',
#   'Confiscated Assets',
#   'Conspiracy Theories',
#   'Cooking Gas',
#   'Corpses',
#   'Corruption',
#   'Crimes Against Humanity',
#   'Cultural Genocide',
#   'Death',
#   'Debunked',
#   'Dehumanization',
#   'Demolition',
#   'Desecration of Bodies',
#   'Destruction',
#   'Destruction of Cultural Sites',
#   'Detainees',
#   'Detention Center',
#   'Diplomacy',
#   'Disability',
#   'Disease',
#   'Disengagement (2005)',
#   'Disturbing Content',
#   'Doctors Testimonies',
#   'Domicide',
#   'Double Tap Strike',
#   'Doubting the Gaza Death Toll',
#   'Drone / Quadcopter',
#   'Economy',
#   'Education',
#   'Elderly',
#   'Electricity',
#   'Emigration',
#   'Ethnic Cleansing',
#   'Execution',
#   'Explosives',
#   'Explosive Injuries',
#   'Family',
#   'Famine',
#   'Food',
#   'Fuel',
#   'Funding',
#   'Forced Displacement',
#   'Gaza Death Toll',
#   'Gaza US Pier',
#   'Genocide',
#   'Geolocation',
#   'Global Comparisons',
#   'Ground Operation',
#   'Gunshot Wounds',
#   'Hannibal Directive',
#   'Healthcare Workers',
#   'Hospital',
#   'Hospital Conditions',
#   'Hostage Deal',
#   'Hostage Rescue Operation',
#   'Hostages',
#   'Human Shields',
#   'Humanitarian Aid',
#   'Humanitarian Crisis',
#   'Humanitarian Law',
#   'Humiliation',
#   'Hygiene Issues',
#   'Incitement to Genocide',
#   'Incitement to Violence',
#   'Indiscriminate Shooting',
#   'Infants',
#   'Infrastructure',
#   'Injury',
#   'International Responsibility',
#   'International Sanctions',
#   'Interview',
#   'Iron Dome',
#   'Islamophobia',
#   'Israeli Education System',
#   'Israeli Far Right',
#   'Israeli Media',
#   'Israeli Negotiation Team',
#   'Israeli Political Right',
#   'Israeli Society',
#   'Israeli Soldier Movies',
#   'Israeli Soldier Photos',
#   'Israeli Soldier Testimonies',
#   'Jewish Settlements in Gaza',
#   'Journalistic Report',
#   'Journalists',
#   'Killing of Journalists',
#   'Leahy Law',
#   'Limiting Free Speech',
#   'Looting',
#   'Malnutrition',
#   'Massacres',
#   'Mass Casualty',
#   'Mass Graves',
#   'Mass Killing',
#   'Media',
#   'Media Bias',
#   'Medical Equipment',
#   'Medical Supplies',
#   'Medicine',
#   'Military Bases',
#   'Military Correspondent',
#   'Missing People',
#   'Misleading/Partially False',
#   'Mockery',
#   'Mortar',
#   'Mosques',
#   'Murder',
#   'Mourning',
#   'Nakba',
#   'News',
#   'Occupied Territories',
#   'October 7th 2023',
#   'Official Report',
#   'Official Statement',
#   'Open Letter',
#   'Opinion',
#   'Orphans',
#   'Palestinian Citizens of Israel',
#   'Palestinian flag',
#   'Palestinian Militants',
#   'Palestinian Testimony',
#   'Poll',
#   'Poverty',
#   'Pregnancy',
#   'Prisoners',
#   'Propaganda',
#   'Protest (International)',
#   'Protest (Israel)',
#   'Protest (Palestinians)',
#   'Psychological Trauma',
#   'Psychological Warfare',
#   'Public Debate',
#   'Public Health',
#   'Public Opinion',
#   'Quantitative Data',
#   'Quran',
#   'Racism',
#   'Rafah Red Line',
#   'Reconstruction',
#   'Refugees',
#   'Refugee Camp',
#   'Religious Right',
#   'Rubble',
#   'Rules of Engagement',
#   'Running Over',
#   'Safe Zones',
#   'Sanitation',
#   'Satellite images',
#   'Scholasticide',
#   'Schools',
#   'Settlements',
#   'Settler Violence',
#   'Severe Illnesses',
#   'Sexual Violence',
#   'Shooting',
#   'Snipers',
#   'Social Media',
#   'Starvation',
#   'Suicidality',
#   'Summer Conditions',
#   'Surveillance',
#   'Talkbacks',
#   'Tanks',
#   'Targeting Healthcare Workers',
#   'Terrorism',
#   'Testimony',
#   'The Flour Massacre',
#   "The Generals' Plan",
#   'The Witkoff Framework',
#   'Torching Houses',
#   'Torture',
#   'Toys',
#   'Two State Solution',
#   'Universities',
#   'Urbicide',
#   'US-Israeli Relations',
#   'US Military Aid',
#   'Vandalism',
#   'Video Games',
#   'Violence',
#   'War Crimes',
#   'Warning',
#   'Water',
#   'WCNSF (Wounded Child No Surviving Family)',
#   'Winter conditions',
#   'Women',
#   "Women's clothing (inc. lingerie)"],
#  'COUNTRIES_AND_ORGANIZATIONS': ['AIPAC (American Israel Public Affairs Committee)',
#   'ACRI (The association for Civil Rights in Israel)',
#   'Al Jazeera',
#   'Al-Azhar University',
#   'Amnesty International',
#   'Australia',
#   'Bar-Ilan University',
#   'Begin-Sadat Center for Strategic Studies',
#   'COGAT (The Coordination of the Israeli Government Activities in the Territories)',
#   'Columbia University',
#   'Egypt',
#   'Elbit',
#   'EU (European Union)',
#   'FAJR Scientific',
#   'FAO (The Food and Agriculture Organization of the United Nations)',
#   'Foundation for the Defense of Democracies',
#   'Gaza Health Ministry',
#   'Gaza Police',
#   'Germany',
#   'GHF (Gaza Humanitarian Fund)',
#   'Gisha',
#   'Government Media Office of Gaza',
#   'Hamas',
#   'HaMoked Center for the Defense of the Individual',
#   'Heritage for Peace',
#   'Hezbollah',
#   'Hind Rajab Foundation',
#   'HonestReporting',
#   'Hostages and Missing Families Forum',
#   'Houthis (Ansar Allah)',
#   'Human Rights Watch',
#   'IDF (Israel Defense Forces)',
#   'ICC (International Criminal Court)',
#   'ICJ (International Court of Justice)',
#   'ICOMOS (The International Council on Monuments and Sites)',
#   'ICRC (International Committee of the Red Cross)',
#   'Iran',
#   'IRC (International Rescue Committee)',
#   'Islamic Jihad',
#   'Israel Antiquities Authority',
#   'Israeli Education Ministry',
#   'Israeli Foreign Ministry',
#   'Israeli Government',
#   'Israeli Health Ministry',
#   'Israeli Incarceration System',
#   'Israeli Parliament (Knesset)',
#   'Israeli Police',
#   'Israeli Prison',
#   'Israeli Supreme Court',
#   'Jerusalem Institute for Strategy and Security',
#   'Jordan',
#   'JVP (Jewish Voice for Peace)',
#   'Lebanon',
#   'Likud',
#   'MAP (Medical Aid for Palestinians)',
#   'Meta Platforms',
#   'Mossad',
#   'MSF - Médecins Sans Frontières (Doctors Without Borders)',
#   'Nachala (settler movement)',
#   'Norwegian Refugee Council',
#   'OCHA (UN Office for the Coordination of Humanitarian Affairs)',
#   'Palestinian Authority',
#   'Palestinian Football Association',
#   'PAMA (Palestinian American Medical Association)',
#   'PCD (Palestinian Civil Defence)',
#   'Physicians for Human Rights Israel',
#   'Palestinian Ministry of Education',
#   'PRCS (Palestinian Red Crescent Society)',
#   'Project HOPE',
#   'Qatar',
#   'Saudi Arabia',
#   'Shin Bet',
#   'South Africa',
#   'Syria',
#   'Tsav 9',
#   'UN (United Nations)',
#   'UNESCO (United Nations Educational Scientific and Cultural Organization)',
#   'UNFPA (United Nations Population Fund)',
#   "UNICEF (United Nations Children's Fund)",
#   'United Kingdom',
#   'United States',
#   'UNRWA (The UN Relief and Works Agency for Palestine Refugees)',
#   'UN Security Council',
#   'USAID (United States Agency for International Development)',
#   'US Department of State',
#   'Vatican',
#   'WHO (World Health Organization)',
#   'World Central Kitchen',
#   'World Food Programme',
#   'Zazim'],
#  'LOCATIONS': ['Al Ahli Baptist Hospital',
#   'Al-Amal Hospital',
#   'Al-Aqsa Hospital',
#   'Al Aqsa University',
#   'Al-Awda Hospital',
#   'Al Azhar University',
#   'Al Buriej',
#   'Al Mawasi',
#   'Al-Nasr Hospital',
#   'Al Nazla',
#   'Al-Rantisi Hospital',
#   'Al Rashid Coastal Road',
#   'Al-Shati Refugee Camp',
#   'Al-Shifa Hospital',
#   'Al Yarmouk Stadium Refugee Camp',
#   'Al-Yemen Al-Saeed Hospital',
#   'Ashdod Port',
#   'Beer Sheva',
#   'Beit Hanoun',
#   'Beit Lahiya',
#   'Bethlehem',
#   'Central Gaza Strip',
#   'Central Israel',
#   'Cyprus',
#   'Damon Prison',
#   'Deir al Balah',
#   'East Jerusalem',
#   'Egypt',
#   'Erez Crossing',
#   'Europe',
#   'Gaza City',
#   'Gaza Strip',
#   'Gilboa Prison',
#   'Hebron',
#   'Iran',
#   'Iraq',
#   'Israel',
#   'Israeli Parliament (Knesset)',
#   'Israeli Prison',
#   'Jabaliya',
#   'Jabaliya Camp',
#   'Jabaliya City',
#   'Jenin',
#   'Jericho',
#   'Jerusalem',
#   'Jordan',
#   'Jordan Valley',
#   'Kamal Adwan Hospital',
#   'Karni Crossing',
#   'Kerem Shalom Crossing',
#   'Khan Younis',
#   "Khuza'a",
#   "Ktzi'ot Prison",
#   'Lebanon',
#   'Megido Prison',
#   'Mohammed Yousef El-Najar Hospital',
#   'Morag Corridor',
#   'Nablus',
#   'Nasser Hospital',
#   'Negev',
#   'Netzarim Corridor',
#   'Nitzana Border Crossing',
#   'North Gaza',
#   'Northern Israel',
#   'Nur Shams Refugee Camp',
#   'Nuseirat Refugee Camp',
#   'Philadelphi Corridor',
#   'Qalqilya',
#   'Qatar',
#   'Rafah',
#   'Rafah Crossing',
#   'Ramallah',
#   'Red Cross Field Hospital',
#   'Sde Teiman Detention Center',
#   'Sheikh Radwan',
#   'Shujjaiya',
#   'South Gaza',
#   'Southern Israel',
#   'Tel Aviv',
#   'The European Hospital',
#   'The Indonesian Hospital',
#   'Tul Karem',
#   'Turkish-Palestinian Friendship Hospital',
#   'United Kingdom',
#   'USA',
#   'West Bank',
#   'Western Negev (Otef)',
#   'Zaytun Neighborhood',
#   'Zikim Crossing'],
#  'FIGURES': ['Aaron Bushnell',
#   'Ahmad Tibi',
#   'Almog Boker',
#   'Almog Cohen',
#   'Amihai Eliyahu',
#   'Amit Segal',
#   'António Guterres',
#   'Antony Blinken',
#   'Avera Mengistu',
#   'Avichay Adraee',
#   'Benjamin Netanyahu',
#   'Benny Gantz',
#   'Benny Morris',
#   'Bezalel Smotritch',
#   'Cochav Elkayam-Levy',
#   'Cyril Ramaphosa',
#   'Daniel Hagari',
#   'Daniella Weiss',
#   'Danny Danon',
#   'David Barnea',
#   'Donald Trump',
#   'Dr Adnan Al Bursh',
#   'Dr Hussam Abu Safiya',
#   'Dr Marwan Shafiq Alhamss',
#   'Dr. Refaat Alareer',
#   'Efraim Inbar',
#   'Einav Zangauker',
#   'Eitan Shamir',
#   'Eli Sharabi',
#   'Eyal Zamir',
#   'Fadi Al-Wahidi',
#   'Francesca Albanese',
#   'Gali Baharav-Miara',
#   'Giora Eiland',
#   'Guy Basson',
#   'Guy Hochman',
#   'Hassan Eslieh',
#   'Hassan Nasrallah',
#   'Herzi Halevi',
#   'Hossam Shabat',
#   'Isaac Herzog',
#   'Ismail al-Ghoul',
#   'Ismail Haniyeh',
#   'Israel Katz',
#   'Itamar Ben-Gvir',
#   'James Elder',
#   'Jake Sullivan',
#   'Jibril Ghatab El-Kahlout',
#   'Joe Biden',
#   'John Kirby',
#   'Joseph Borrell',
#   'Kamala Harris',
#   'Karim Khan',
#   'Kobi Yaakobi',
#   'Lloyd Austin',
#   'Mahmoud Abbas',
#   'May Golan',
#   'Merav Michaeli',
#   'Martin Shaw',
#   'Marwan Barghouti',
#   'Mohammed bin Salman Al Saud',
#   'Mosab Abu Toha',
#   'Moshe (Bogie) Yaalon',
#   'Moshe Feiglin',
#   'Mustafa Jamal Kahlout',
#   'Naftali Bennett',
#   'Nissim Vaturi',
#   'Nitzan Alon',
#   'Nir Barkat',
#   'Noam Tibon',
#   'Ofer Cassif',
#   'Omer Bar-Lev',
#   'Philippe Lazzarini',
#   'Pope Francis',
#   'Ron Dermer',
#   'Ronen Bar',
#   'Sarah Netanyahu',
#   'Shimon Boker',
#   'Shimon Riklin',
#   'Steve Witkoff',
#   'Tali Gotliv',
#   'Volker Türk',
#   'Yaakov Bardugo',
#   'Yahya Al-Sinwar',
#   'Yair Golan',
#   'Yair Lapid',
#   'Yehuda Schlesinger',
#   'Yehudah Vach',
#   'Yehuda Vald',
#   'Yinon Magal',
#   'Yoav Gallant',
#   'Zvi Sukkot',
#   'Zvi Yehezkeli']}

# %%
string = ""
for key in DATA_DICT.keys():
    string += f"--{key}--\n{DATA_DICT[key]}\n"

# %%
print(string)
# Out:
# --TYPES--
# ['Official Report', 'Official Statement', 'Opinion', 'Testimony', 'Journalistic Report', 'Analysis', 'Open Letter', 'News', 'Post', 'Poll', 'Press Release', 'Interview']
# --MEDIAS--
# ['Video', 'Photo', 'Audio', 'Text', 'Map', 'Chart']
# --LANGUAGES--
# ['English', 'French', 'Hebrew', 'Arabic']
# --PLATFORMS--
# ['972 Magazine', 'Al Jazeera', 'ABC News', 'Academia', 'ACLED (Armed Conflict Location and Event Data)', 'Adalah', 'Airwars', 'Alaraby', 'AlMamlaka TV', 'Al-Monitor', 'Al Jazeera', 'Amnesty International', 'Anadolu Agency', 'AP News', 'Arab48', 'Arab News', 'Atlantic Council', "Barron's", 'BBC', 'Begin-Sadat Center for Strategic Studies (Bar-Ilan University)', 'Bellingcat', 'Brookings Institute', 'Business Insider', 'Business Standard', 'Calcalist', 'Care.org', 'CBC News', 'CBS', 'Center for Economic and Policy Research', 'Chabad', 'Channel 4', 'Channel 14', 'CIA', 'CNN', 'COGAT (The Coordination of the Israeli Government Activities in the Territories)', 'Common Dreams', 'CPJ', 'Daily Sabah', 'Daily Trojan', 'Decentralize Damage Mapping Group', 'Declassified UK', 'Defense Daily', 'Democracy Now!', 'Drop Site News', 'DW News', 'Euro Gamer', 'Euro-Med Human Rights Monitor', 'Facebook', 'Fair', 'Financial Times', 'First Draft News', 'Foreign Affairs', 'Foreign Policy', 'Forward', 'FOX', 'France 24', 'FRC (Famine Review Committee)', 'Galey Israel', 'Galey Tzahal', 'Gallup', 'Gaza Healthcare Letters', 'GazaMaps', 'Getty Images', 'Global Times', 'Globes', 'GPO (Government Press Office)', 'Haaretz', 'Ha-Makom', 'Hazman Hazeh', 'Hatzinor', 'Heritage for Peace', 'Hernán Reyes Alcaide', 'Hidabroot', 'HRF (The Hind Rajab Foundation)', 'HuffPost', 'Humanity Journal', 'Human Rights Center Antonio Papisca', 'Human Rights Watch', 'IASC (Inter-Agency Standing Committee)', 'ice.co.il', 'ICRC (the International Committee of the Red Cross)', 'iNews', 'Inside Higher Ed', 'INSS (The Institute for National Security Studies)', 'Instagram', 'Institute for Palestine Studies', 'Institute for the Study of War', 'IPC (Integrated Food Security Phase Classification)', 'Israel Hayom', 'ITV News', 'Jacobin', 'JDN News', 'Jerusalem Center for Public Affairs', 'Jewish Currents', 'Jewish Voices for Labour', 'JPPI (The Jewish People Policy Institute)', 'JURIST', 'Just Security', 'Kan 11', 'Ken Klippenstein', 'Keshet 12', 'Kikar Hashabat', 'Knesset Channel 99', 'Kol Barama', 'La Libre', 'La Stampa', 'LBC', 'Le Monde', 'LinkedIn', 'Literary Hub', 'Los Angeles Times', 'Maan News Agency', 'Maariv', 'Mako', 'Makor Rishon', 'Mekomit', 'Middle East Eye', 'Middle East Institute', 'Middle East Monitor', 'Middle East Studies Association', 'Midgam', 'Modern War Institute', 'Mondoweiss', 'MSF - Médecins Sans Frontières (Doctors Without Borders)', 'MSNBC', 'NBC', 'New Line Magazine', 'Newsweek', 'NPR', 'OCHA (UN office for the Coordination of Humanitarian Affairs)', 'OnoNews', 'Oxfam International', 'palestine.beehiiv.com', 'Palestine Chronicle', 'PBS', 'PCATI (The Public Committee Against Torture in Isael)', 'Pew Research Center', 'PFA - The Foreign Press Association', 'Physicians for Human Rights', 'PLOS Medicine', 'Politicallycorret', 'Politico', 'ProPublica', 'Refugees International', 'PSR (Palestine Center for Policy and Seurvey Research)', 'Reader Supported News', 'Reporters Without Borders', 'ReliefWeb', 'Reprieve', 'Reshet 13', 'Responsible Statecraft', 'Rolling Stone', 'Scribd', 'Salon News', 'Semafor', 'Sky News', 'Snopes', 'Snd News Agency', 'Spotify', 'Starts and Stripes', 'Substack', 'Tablet Magazine', 'Telegram', 'Telegraph', 'The Art Newspaper', 'The Association for Civil Rights in Israel', 'The Atlantic', 'The Baffler', 'The Breach', 'The Columbia Daily Spectator', 'The Column', 'The Communist Party of Israel', 'The Conversation U.S', 'The Daily Beast', 'The Daily Pennsylvanian', 'The Economist', 'The Forum for Regional Thinking', 'The Forward', 'The Guardian', 'The Intercept', 'The Israel Democracy Institute', 'The Jerusalem post', 'The Lancet', 'The Marker', 'The Nation', 'The National', 'The New Arab', 'The New Republic', 'The New Yorker', 'The New York Review', 'The New York Times', 'The New York War Crimes', 'The Palestinian Information Center', 'The Presidency of the Republic of South Africa', 'The Seventh Eye', 'The Telegraph', 'The Times', 'The Times  ...
# --THEMES--
# ['2000 Pound Bomb', 'Abduction', 'Abuse', 'Academia', 'Accountability', 'Administrative Detention', 'Advertisement', 'Agriculture', 'AI (Artificial Intelligence)', 'Aid Distribution', 'Aid Workers', 'Airdrops', 'Air Strike', 'Amalek', 'American Society', 'Amputation', 'Analysis', 'Animals', 'Annexation', 'Antisemitism', 'Apartheid', 'Appeal to World Leaders', 'Archaeological Findings', 'Arms Shipments', 'Arrest', 'Assassination', 'Attacks on Aid Centers', 'Attacks on Police', 'Blockade', 'Blocking Aid', 'Bombing', 'Books', 'Buildings', 'Burial', 'Burn Injuries', 'Burning', 'Cages', 'Campaign against UNRWA', 'Campus Protests', 'Captivity Conditions', 'Ceasefire', 'Cemetery', 'Censorship', 'Children', 'Civilians', 'Collective Punishment', 'Combat Footage', 'Communication Blackout', 'Conscientious Objection', 'Confiscated Assets', 'Conspiracy Theories', 'Cooking Gas', 'Corpses', 'Corruption', 'Crimes Against Humanity', 'Cultural Genocide', 'Death', 'Debunked', 'Dehumanization', 'Demolition', 'Desecration of Bodies', 'Destruction', 'Destruction of Cultural Sites', 'Detainees', 'Detention Center', 'Diplomacy', 'Disability', 'Disease', 'Disengagement (2005)', 'Disturbing Content', 'Doctors Testimonies', 'Domicide', 'Double Tap Strike', 'Doubting the Gaza Death Toll', 'Drone / Quadcopter', 'Economy', 'Education', 'Elderly', 'Electricity', 'Emigration', 'Ethnic Cleansing', 'Execution', 'Explosives', 'Explosive Injuries', 'Family', 'Famine', 'Food', 'Fuel', 'Funding', 'Forced Displacement', 'Gaza Death Toll', 'Gaza US Pier', 'Genocide', 'Geolocation', 'Global Comparisons', 'Ground Operation', 'Gunshot Wounds', 'Hannibal Directive', 'Healthcare Workers', 'Hospital', 'Hospital Conditions', 'Hostage Deal', 'Hostage Rescue Operation', 'Hostages', 'Human Shields', 'Humanitarian Aid', 'Humanitarian Crisis', 'Humanitarian Law', 'Humiliation', 'Hygiene Issues', 'Incitement to Genocide', 'Incitement to Violence', 'Indiscriminate Shooting', 'Infants', 'Infrastructure', 'Injury', 'International Responsibility', 'International Sanctions', 'Interview', 'Iron Dome', 'Islamophobia', 'Israeli Education System', 'Israeli Far Right', 'Israeli Media', 'Israeli Negotiation Team', 'Israeli Political Right', 'Israeli Society', 'Israeli Soldier Movies', 'Israeli Soldier Photos', 'Israeli Soldier Testimonies', 'Jewish Settlements in Gaza', 'Journalistic Report', 'Journalists', 'Killing of Journalists', 'Leahy Law', 'Limiting Free Speech', 'Looting', 'Malnutrition', 'Massacres', 'Mass Casualty', 'Mass Graves', 'Mass Killing', 'Media', 'Media Bias', 'Medical Equipment', 'Medical Supplies', 'Medicine', 'Military Bases', 'Military Correspondent', 'Missing People', 'Misleading/Partially False', 'Mockery', 'Mortar', 'Mosques', 'Murder', 'Mourning', 'Nakba', 'News', 'Occupied Territories', 'October 7th 2023', 'Official Report', 'Official Statement', 'Open Letter', 'Opinion', 'Orphans', 'Palestinian Citizens of Israel', 'Palestinian flag', 'Palestinian Militants', 'Palestinian Testimony', 'Poll', 'Poverty', 'Pregnancy', 'Prisoners', 'Propaganda', 'Protest (International)', 'Protest (Israel)', 'Protest (Palestinians)', 'Psychological Trauma', 'Psychological Warfare', 'Public Debate', 'Public Health', 'Public Opinion', 'Quantitative Data', 'Quran', 'Racism', 'Rafah Red Line', 'Reconstruction', 'Refugees', 'Refugee Camp', 'Religious Right', 'Rubble', 'Rules of Engagement', 'Running Over', 'Safe Zones', 'Sanitation', 'Satellite images', 'Scholasticide', 'Schools', 'Settlements', 'Settler Violence', 'Severe Illnesses', 'Sexual Violence', 'Shooting', 'Snipers', 'Social Media', 'Starvation', 'Suicidality', 'Summer Conditions', 'Surveillance', 'Talkbacks', 'Tanks', 'Targeting Healthcare Workers', 'Terrorism', 'Testimony', 'The Flour Massacre', "The Generals' Plan", 'The Witkoff Framework', 'Torching Houses', 'Torture', 'Toys', 'Two State Solution', 'Universities', 'Urbicide', 'US-Israeli Relations', 'US Military Aid', 'Vandalism', 'Video Games', 'Violence', 'War Crimes', 'Wa ...
# --COUNTRIES_AND_ORGANIZATIONS--
# ['AIPAC (American Israel Public Affairs Committee)', 'ACRI (The association for Civil Rights in Israel)', 'Al Jazeera', 'Al-Azhar University', 'Amnesty International', 'Australia', 'Bar-Ilan University', 'Begin-Sadat Center for Strategic Studies', 'COGAT (The Coordination of the Israeli Government Activities in the Territories)', 'Columbia University', 'Egypt', 'Elbit', 'EU (European Union)', 'FAJR Scientific', 'FAO (The Food and Agriculture Organization of the United Nations)', 'Foundation for the Defense of Democracies', 'Gaza Health Ministry', 'Gaza Police', 'Germany', 'GHF (Gaza Humanitarian Fund)', 'Gisha', 'Government Media Office of Gaza', 'Hamas', 'HaMoked Center for the Defense of the Individual', 'Heritage for Peace', 'Hezbollah', 'Hind Rajab Foundation', 'HonestReporting', 'Hostages and Missing Families Forum', 'Houthis (Ansar Allah)', 'Human Rights Watch', 'IDF (Israel Defense Forces)', 'ICC (International Criminal Court)', 'ICJ (International Court of Justice)', 'ICOMOS (The International Council on Monuments and Sites)', 'ICRC (International Committee of the Red Cross)', 'Iran', 'IRC (International Rescue Committee)', 'Islamic Jihad', 'Israel Antiquities Authority', 'Israeli Education Ministry', 'Israeli Foreign Ministry', 'Israeli Government', 'Israeli Health Ministry', 'Israeli Incarceration System', 'Israeli Parliament (Knesset)', 'Israeli Police', 'Israeli Prison', 'Israeli Supreme Court', 'Jerusalem Institute for Strategy and Security', 'Jordan', 'JVP (Jewish Voice for Peace)', 'Lebanon', 'Likud', 'MAP (Medical Aid for Palestinians)', 'Meta Platforms', 'Mossad', 'MSF - Médecins Sans Frontières (Doctors Without Borders)', 'Nachala (settler movement)', 'Norwegian Refugee Council', 'OCHA (UN Office for the Coordination of Humanitarian Affairs)', 'Palestinian Authority', 'Palestinian Football Association', 'PAMA (Palestinian American Medical Association)', 'PCD (Palestinian Civil Defence)', 'Physicians for Human Rights Israel', 'Palestinian Ministry of Education', 'PRCS (Palestinian Red Crescent Society)', 'Project HOPE', 'Qatar', 'Saudi Arabia', 'Shin Bet', 'South Africa', 'Syria', 'Tsav 9', 'UN (United Nations)', 'UNESCO (United Nations Educational Scientific and Cultural Organization)', 'UNFPA (United Nations Population Fund)', "UNICEF (United Nations Children's Fund)", 'United Kingdom', 'United States', 'UNRWA (The UN Relief and Works Agency for Palestine Refugees)', 'UN Security Council', 'USAID (United States Agency for International Development)', 'US Department of State', 'Vatican', 'WHO (World Health Organization)', 'World Central Kitchen', 'World Food Programme', 'Zazim']
# --LOCATIONS--
# ['Al Ahli Baptist Hospital', 'Al-Amal Hospital', 'Al-Aqsa Hospital', 'Al Aqsa University', 'Al-Awda Hospital', 'Al Azhar University', 'Al Buriej', 'Al Mawasi', 'Al-Nasr Hospital', 'Al Nazla', 'Al-Rantisi Hospital', 'Al Rashid Coastal Road', 'Al-Shati Refugee Camp', 'Al-Shifa Hospital', 'Al Yarmouk Stadium Refugee Camp', 'Al-Yemen Al-Saeed Hospital', 'Ashdod Port', 'Beer Sheva', 'Beit Hanoun', 'Beit Lahiya', 'Bethlehem', 'Central Gaza Strip', 'Central Israel', 'Cyprus', 'Damon Prison', 'Deir al Balah', 'East Jerusalem', 'Egypt', 'Erez Crossing', 'Europe', 'Gaza City', 'Gaza Strip', 'Gilboa Prison', 'Hebron', 'Iran', 'Iraq', 'Israel', 'Israeli Parliament (Knesset)', 'Israeli Prison', 'Jabaliya', 'Jabaliya Camp', 'Jabaliya City', 'Jenin', 'Jericho', 'Jerusalem', 'Jordan', 'Jordan Valley', 'Kamal Adwan Hospital', 'Karni Crossing', 'Kerem Shalom Crossing', 'Khan Younis', "Khuza'a", "Ktzi'ot Prison", 'Lebanon', 'Megido Prison', 'Mohammed Yousef El-Najar Hospital', 'Morag Corridor', 'Nablus', 'Nasser Hospital', 'Negev', 'Netzarim Corridor', 'Nitzana Border Crossing', 'North Gaza', 'Northern Israel', 'Nur Shams Refugee Camp', 'Nuseirat Refugee Camp', 'Philadelphi Corridor', 'Qalqilya', 'Qatar', 'Rafah', 'Rafah Crossing', 'Ramallah', 'Red Cross Field Hospital', 'Sde Teiman Detention Center', 'Sheikh Radwan', 'Shujjaiya', 'South Gaza', 'Southern Israel', 'Tel Aviv', 'The European Hospital', 'The Indonesian Hospital', 'Tul Karem', 'Turkish-Palestinian Friendship Hospital', 'United Kingdom', 'USA', 'West Bank', 'Western Negev (Otef)', 'Zaytun Neighborhood', 'Zikim Crossing']
# --FIGURES--
# ['Aaron Bushnell', 'Ahmad Tibi', 'Almog Boker', 'Almog Cohen', 'Amihai Eliyahu', 'Amit Segal', 'António Guterres', 'Antony Blinken', 'Avera Mengistu', 'Avichay Adraee', 'Benjamin Netanyahu', 'Benny Gantz', 'Benny Morris', 'Bezalel Smotritch', 'Cochav Elkayam-Levy', 'Cyril Ramaphosa', 'Daniel Hagari', 'Daniella Weiss', 'Danny Danon', 'David Barnea', 'Donald Trump', 'Dr Adnan Al Bursh', 'Dr Hussam Abu Safiya', 'Dr Marwan Shafiq Alhamss', 'Dr. Refaat Alareer', 'Efraim Inbar', 'Einav Zangauker', 'Eitan Shamir', 'Eli Sharabi', 'Eyal Zamir', 'Fadi Al-Wahidi', 'Francesca Albanese', 'Gali Baharav-Miara', 'Giora Eiland', 'Guy Basson', 'Guy Hochman', 'Hassan Eslieh', 'Hassan Nasrallah', 'Herzi Halevi', 'Hossam Shabat', 'Isaac Herzog', 'Ismail al-Ghoul', 'Ismail Haniyeh', 'Israel Katz', 'Itamar Ben-Gvir', 'James Elder', 'Jake Sullivan', 'Jibril Ghatab El-Kahlout', 'Joe Biden', 'John Kirby', 'Joseph Borrell', 'Kamala Harris', 'Karim Khan', 'Kobi Yaakobi', 'Lloyd Austin', 'Mahmoud Abbas', 'May Golan', 'Merav Michaeli', 'Martin Shaw', 'Marwan Barghouti', 'Mohammed bin Salman Al Saud', 'Mosab Abu Toha', 'Moshe (Bogie) Yaalon', 'Moshe Feiglin', 'Mustafa Jamal Kahlout', 'Naftali Bennett', 'Nissim Vaturi', 'Nitzan Alon', 'Nir Barkat', 'Noam Tibon', 'Ofer Cassif', 'Omer Bar-Lev', 'Philippe Lazzarini', 'Pope Francis', 'Ron Dermer', 'Ronen Bar', 'Sarah Netanyahu', 'Shimon Boker', 'Shimon Riklin', 'Steve Witkoff', 'Tali Gotliv', 'Volker Türk', 'Yaakov Bardugo', 'Yahya Al-Sinwar', 'Yair Golan', 'Yair Lapid', 'Yehuda Schlesinger', 'Yehudah Vach', 'Yehuda Vald', 'Yinon Magal', 'Yoav Gallant', 'Zvi Sukkot', 'Zvi Yehezkeli']

# %%
df = pd.read_excel("/Users/delmedigo/Dev/langtest/langscrape/data/TAGS.xlsx")

# %%
TAGS = [TYPES, MEDIAS, LANGUAGES, PLATFORMS, THEMES, COUNTRIES_AND_ORGANIZATIONS, LOCATIONS, FIGURES]

# %%
TYPES.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 TYPES.__name__
#
# AttributeError: 'list' object has no attribute '__name__'

# %%
def str_to_list(string):
    return
